# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pycountry_convert as pc
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import model_selection
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
import seaborn as sns

# %%
df=pd.read_csv('time-series-19-covid-combined_csv.csv') ## get the data into a dataframe from the csv file

# %%
df.head()
# Out:
#       Date Country/Region Province/State   Lat  Long  Confirmed  Recovered  \
# 0  1/22/20    Afghanistan            NaN  33.0  65.0          0        0.0
# 1  1/23/20    Afghanistan            NaN  33.0  65.0          0        0.0
# 2  1/24/20    Afghanistan            NaN  33.0  65.0          0        0.0
# 3  1/25/20    Afghanistan            NaN  33.0  65.0          0        0.0
# 4  1/26/20    Afghanistan            NaN  33.0  65.0          0        0.0
#
#    Deaths
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.shape ## get the number of rows & columns
# Out:
# (14632, 8)

# %%
df.head(14756)
# Out:
#           Date Country/Region Province/State      Lat     Long  Confirmed  \
# 0      1/22/20    Afghanistan            NaN  33.0000  65.0000          0
# 1      1/23/20    Afghanistan            NaN  33.0000  65.0000          0
# 2      1/24/20    Afghanistan            NaN  33.0000  65.0000          0
# 3      1/25/20    Afghanistan            NaN  33.0000  65.0000          0
# 4      1/26/20    Afghanistan            NaN  33.0000  65.0000          0
# ...        ...            ...            ...      ...      ...        ...
# 14627  3/19/20         Belize            NaN  13.1939 -59.5432          0
# 14628  3/20/20         Belize            NaN  13.1939 -59.5432          0
# 14629  3/21/20         Belize            NaN  13.1939 -59.5432          0
# 14630  3/22/20         Belize            NaN  13.1939 -59.5432          0
# 14631  3/23/20         Belize            NaN  13.1939 -59.5432          1
#
#        Recovered  Deaths
# 0            0.0       0
# 1            0.0       0
# 2            0.0       0
# 3            0.0       0
# 4            0.0       0
# ...          ...     ...
# 14627        NaN       0
# 14628        NaN       0
# 14629        NaN       0
# 14630        NaN       0
# 14631        NaN       0
#
# [14632 rows x 8 columns]

# %%
df.describe() ## some statistics
# Out:
#                 Lat          Long     Confirmed     Recovered        Deaths
# count  14632.000000  14632.000000  14632.000000  14012.000000  14632.000000
# mean      22.187318     25.549175    379.287794    140.625963     13.570804
# std       24.644875     70.791972   3820.237046   2100.868888    180.343477
# min      -41.454500   -123.120700      0.000000      0.000000      0.000000
# 25%        8.390125    -14.666825      0.000000      0.000000      0.000000
# 50%       25.004150     21.758700      0.000000      0.000000      0.000000
# 75%       41.435275     88.569300     16.000000      1.000000      0.000000
# max       71.706900    178.065000  67800.000000  59879.000000   6077.000000

# %%
df=df.drop_duplicates() ## removing any duplicates (if any) 
df=df.reset_index(drop=True) ## Reset the indices if duplicates were found

# %%
df.shape
# Out:
# (14632, 8)

# %%
df.isnull() ## Get where there are missing values
# Out:
#         Date  Country/Region  Province/State    Lat   Long  Confirmed  \
# 0      False           False            True  False  False      False
# 1      False           False            True  False  False      False
# 2      False           False            True  False  False      False
# 3      False           False            True  False  False      False
# 4      False           False            True  False  False      False
# ...      ...             ...             ...    ...    ...        ...
# 14627  False           False            True  False  False      False
# 14628  False           False            True  False  False      False
# 14629  False           False            True  False  False      False
# 14630  False           False            True  False  False      False
# 14631  False           False            True  False  False      False
#
#        Recovered  Deaths
# 0          False   False
# 1          False   False
# 2          False   False
# 3          False   False
# 4          False   False
# ...          ...     ...
# 14627       True   False
# 14628       True   False
# 14629       True   False
# 14630       True   False
# 14631       True   False
#
# [14632 rows x 8 columns]

# %%
df=df.interpolate() ## interpolate what can be interpolated (i.e., "Recovered")
df['Province/State'].fillna('Not Applicable', inplace=True) ## Fill missing values in the state column by "Not Applicable"

# %%
df.isnull() ## check if replacment was successful
# Out:
#         Date  Country/Region  Province/State    Lat   Long  Confirmed  \
# 0      False           False           False  False  False      False
# 1      False           False           False  False  False      False
# 2      False           False           False  False  False      False
# 3      False           False           False  False  False      False
# 4      False           False           False  False  False      False
# ...      ...             ...             ...    ...    ...        ...
# 14627  False           False           False  False  False      False
# 14628  False           False           False  False  False      False
# 14629  False           False           False  False  False      False
# 14630  False           False           False  False  False      False
# 14631  False           False           False  False  False      False
#
#        Recovered  Deaths
# 0          False   False
# 1          False   False
# 2          False   False
# 3          False   False
# 4          False   False
# ...          ...     ...
# 14627      False   False
# 14628      False   False
# 14629      False   False
# 14630      False   False
# 14631      False   False
#
# [14632 rows x 8 columns]

# %%
import pycountry_convert as pc

def country_to_continent(country_name):
    country_alpha2 = pc.country_name_to_country_alpha2(country_name)
    country_continent_code = pc.country_alpha2_to_continent_code(country_alpha2)
    country_continent_name = pc.convert_continent_code_to_continent_name(country_continent_code)
    return country_continent_name


country_name = 'United States'
print(country_to_continent(country_name))

i=5146
while i < 5270:
    df.iloc[i,1]='Congo'
    i += 1

df.iloc[5335,1]


i=5332
while i < 5394:
    df.iloc[i,1]='Ivory Coast'
    i += 1



i=7812
while i < 7874:
    df.iloc[i,1]='Italy'
    i += 1
    
i=8804
while i < 8866:
    df.iloc[i,1]='South Korea'
    i += 1


i=12772
while i < 12834:
    df.iloc[i,1]='Taiwan'
    i += 1


i=13888
while i < 13950:
    df.iloc[i,1]='United States'
    i += 1
# Out:
# North America

# %%
mylist = []

for index, row in df.iterrows():
    mylist += [country_to_continent(row['Country/Region'])]

# %%
df=df.reset_index(drop=True)

# %%
df['Continent'] = mylist

# %%
df
# Out:
#           Date Country/Region  Province/State      Lat     Long  Confirmed  \
# 0      1/22/20    Afghanistan  Not Applicable  33.0000  65.0000          0
# 1      1/23/20    Afghanistan  Not Applicable  33.0000  65.0000          0
# 2      1/24/20    Afghanistan  Not Applicable  33.0000  65.0000          0
# 3      1/25/20    Afghanistan  Not Applicable  33.0000  65.0000          0
# 4      1/26/20    Afghanistan  Not Applicable  33.0000  65.0000          0
# ...        ...            ...             ...      ...      ...        ...
# 14627  3/19/20         Belize  Not Applicable  13.1939 -59.5432          0
# 14628  3/20/20         Belize  Not Applicable  13.1939 -59.5432          0
# 14629  3/21/20         Belize  Not Applicable  13.1939 -59.5432          0
# 14630  3/22/20         Belize  Not Applicable  13.1939 -59.5432          0
# 14631  3/23/20         Belize  Not Applicable  13.1939 -59.5432          1
#
#        Recovered  Deaths      Continent
# 0            0.0       0           Asia
# 1            0.0       0           Asia
# 2            0.0       0           Asia
# 3            0.0       0           Asia
# 4            0.0       0           Asia
# ...          ...     ...            ...
# 14627        0.0       0  North America
# 14628        0.0       0  North America
# 14629        0.0       0  North America
# 14630        0.0       0  North America
# 14631        0.0       0  North America
#
# [14632 rows x 9 columns]

# %%
ax = sns.lmplot(x = 'Long', y = 'Confirmed', data = df)

# %%
ax2 = sns.lmplot(x = 'Lat', y = 'Confirmed', data = df)

# %%
df2 = sns.barplot(x = 'Continent', y = 'Deaths', data = df)

# %%
df3 = sns.barplot(x = 'Continent', y = 'Confirmed', data = df)

# %%
df4 = sns.barplot(x = 'Continent', y = 'Recovered', data = df)

# %%
china_canada = df.loc[df['Country/Region'].isin(['China', 'Canada'])]
china_canada
# Out:
#           Date Country/Region    Province/State      Lat      Long  Confirmed  \
# 2170   1/22/20         Canada           Alberta  53.9333 -116.5765          0
# 2171   1/23/20         Canada           Alberta  53.9333 -116.5765          0
# 2172   1/24/20         Canada           Alberta  53.9333 -116.5765          0
# 2173   1/25/20         Canada           Alberta  53.9333 -116.5765          0
# 2174   1/26/20         Canada           Alberta  53.9333 -116.5765          0
# ...        ...            ...               ...      ...       ...        ...
# 14317  3/19/20         Canada  Diamond Princess   0.0000    0.0000          0
# 14318  3/20/20         Canada  Diamond Princess   0.0000    0.0000          0
# 14319  3/21/20         Canada  Diamond Princess   0.0000    0.0000          0
# 14320  3/22/20         Canada  Diamond Princess   0.0000    0.0000          0
# 14321  3/23/20         Canada  Diamond Princess   0.0000    0.0000          0
#
#        Recovered  Deaths      Continent
# 2170         0.0       0  North America
# 2171         0.0       0  North America
# 2172         0.0       0  North America
# 2173         0.0       0  North America
# 2174         0.0       0  North America
# ...          ...     ...            ...
# 14317        0.0       0  North America
# 14318        0.0       0  North America
# 14319        0.0       0  North America
# 14320        0.0       1  North America
# 14321        0.0       1  North America
#
# [2790 rows x 9 columns]

# %%
# Test/Train data ML

target = china_canada['Province/State']
features = china_canada[['Confirmed','Deaths','Lat']]

y = target.values
X = features.values
seed = 50
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = seed)

# %%
print(X.shape)
# Out:
# (2790, 3)

# %%
print(y.shape)
# Out:
# (2790,)

# %%
print(X_test.shape)
# Out:
# (558, 3)

# %%
print(y_test.shape)
# Out:
# (558,)

# %%
# Report accuracy of KNN model
knn3 = KNeighborsClassifier(n_neighbors = 2)
knn3.fit(X_train,y_train)
preds = knn3.predict(X_test)
accuracy_score(y_true = y_test, y_pred = preds)
# Out:
# 0.7078853046594982

# %%
matrix = confusion_matrix(y_test, preds)
print(matrix)
# Out:
# [[15  0  0 ...  0  0  0]
#  [ 0  4  0 ...  0  0  0]
#  [ 0  0  7 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  5  0  0]
#  [ 0  0  0 ...  0 10  0]
#  [ 0  1  0 ...  0  0  9]]

# %%
report = classification_report(y_test, preds)
print(report)
# Out:
#                            precision    recall  f1-score   support
#
#                   Alberta       0.88      0.88      0.88        17
#                     Anhui       0.27      0.40      0.32        10
#                   Beijing       0.44      0.54      0.48        13
#          British Columbia       0.46      0.67      0.55         9
#                 Chongqing       0.35      0.89      0.50         9
#          Diamond Princess       1.00      1.00      1.00        13
#                    Fujian       0.43      0.82      0.56        11
#                     Gansu       0.60      0.75      0.67        12
#            Grand Princess       0.82      1.00      0.90        14
#                 Guangdong       0.35      0.67      0.46         9
#                   Guangxi       0.68      0.76      0.72        17
#                   Guizhou       0.75      0.69      0.72        13
#                    Hainan       0.75      0.82      0.78        11
#                     Hebei       0.82      0.75      0.78        12
#              Heilongjiang       0.56      0.38      0.45        13
#                     Henan       0.60      0.53      0.56        17
#                 Hong Kong       1.00      0.30      0.46        10
#                     Hubei       1.00      0.89      0.94         9
#                     Hunan       0.80      0.73      0.76        11
#            Inner Mongolia       0.75      0.79      0.77        19
#                   Jiangsu       0.33      0.33      0.33         9
#                   Jiangxi       0.78      0.54      0.64        13
#                     Jilin       0.69      0.75      0.72        12
#                  Liaoning       0.57      1.00      0.73         8
#                     Macau       0.91      0.91      0.91        11
#                  Manitoba       1.00      1.00      1.00        14
#             New Brunswick       0.92      0.92      0.92        13
# Newfoundland and Labrador       0.91      0.91      0.91        11
#                   Ningxia       0.56      0.71      0.63        14
#               Nova Scotia       1.00      0.75      0.86        12
#                   Ontario       0.85      0.65      0.73        17
#      Prince Edward Island       0.86      1.00      0.92        12
#                   Qinghai       0.95      1.00      0.97        19
#                    Quebec       0.67      0.18      0.29        11
#              Saskatchewan       0.47      0.80      0.59        10
#                   Shaanxi       0.70      0.70      0.70        10
#                  Shandong       0.86      0.55      0.67        11
#                  Shanghai       0.78      0.44      0.56        16
#                    Shanxi       0.83      0.50      0.62        10
#                   Sichuan       0.83      0.38      0.53        13
#                   Tianjin       0.71      0.50      0.59        10
#                     Tibet       1.00      1.00      1.00        13
#                  Xinjiang       1.00      0.62      0.77         8
#                    Yunnan       1.00      0.59      0.74        17
#                  Zhejiang       0.82      0.60      0.69        15
#
#                  accuracy                           0.71       558
#                 macro avg       0.74      0.70      0.70       558
#              weighted avg       0.75      0.71      0.71       558

# %%
n = list(range(1,10))
score = []
for i in n:
    k = KNeighborsClassifier(n_neighbors = i)
    k.fit(X_train, y_train)
    p = k.predict(X_test)
    score.append(accuracy_score(y_true = y_test, y_pred = p))
score
# Out:
# [0.7275985663082437,
#  0.7078853046594982,
#  0.7060931899641577,
#  0.7060931899641577,
#  0.6845878136200717,
#  0.6989247311827957,
#  0.6917562724014337,
#  0.6881720430107527,
#  0.6899641577060932]

# %%
plt.plot(n, score)
plt.xlabel('Value of K for KNN of X')
plt.ylabel('Testing Accuracy')
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
cc1 = china_canada.sort_values(["Lat", "Confirmed"], ascending = (True, True))
cc1 = cc1[cc1['Date'] == "3/23/20"]
cc1=cc1.reset_index(drop=True)
del cc1['Long']
del cc1['Continent']
del cc1['Deaths']
del cc1['Recovered']
cc1 = cc1.drop(cc1.index[14])
cc1=cc1.reset_index(drop=True)
cc1
# Out:
#        Date Country/Region             Province/State      Lat  Confirmed
# 0   3/23/20         Canada           Diamond Princess   0.0000          0
# 1   3/23/20          China                     Hainan  19.1959        168
# 2   3/23/20          China                      Macau  22.1667         24
# 3   3/23/20          China                  Hong Kong  22.3000        356
# 4   3/23/20          China                  Guangdong  23.3417       1415
# 5   3/23/20          China                    Guangxi  23.8298        254
# 6   3/23/20          China                     Yunnan  24.9740        176
# 7   3/23/20          China                     Fujian  26.0789        313
# 8   3/23/20          China                    Guizhou  26.8154        146
# 9   3/23/20          China                      Hunan  27.6104       1018
# 10  3/23/20          China                    Jiangxi  27.6140        936
# 11  3/23/20          China                   Zhejiang  29.1832       1238
# 12  3/23/20          China                  Chongqing  30.0572        578
# 13  3/23/20          China                    Sichuan  30.6171        543
# 14  3/23/20          China                   Shanghai  31.2020        404
# 15  3/23/20          China                      Tibet  31.6927          1
# 16  3/23/20          China                      Anhui  31.8257        990
# 17  3/23/20          China                    Jiangsu  32.9711        633
# 18  3/23/20          China                      Henan  33.8820       1274
# 19  3/23/20          China                    Shaanxi  35.1917        248
# 20  3/23/20          China                    Qinghai  35.7452         18
# 21  3/23/20          China                   Shandong  36.3427        768
# 22  3/23/20          China                    Ningxia  37.2692         75
# 23  3/23/20          China                     Shanxi  37.5777        134
# 24  3/23/20         Canada             Grand Princess  37.6489         13
# 25  3/23/20          China                      Gansu  37.8099        136
# 26  3/23/20          China                    Tianjin  39.3054        141
# 27  3/23/20          China                      Hebei  39.5490        319
# 28  3/23/20          China                    Beijing  40.1824        537
# 29  3/23/20          China                   Xinjiang  41.1129         76
# 30  3/23/20          China                   Liaoning  41.2956        127
# 31  3/23/20          China                      Jilin  43.6661         93
# 32  3/23/20          China             Inner Mongolia  44.0935         75
# 33  3/23/20         Canada                Nova Scotia  44.6820         41
# 34  3/23/20         Canada       Prince Edward Island  46.5107          3
# 35  3/23/20         Canada              New Brunswick  46.5653         17
# 36  3/23/20          China               Heilongjiang  47.8620        484
# 37  3/23/20         Canada           British Columbia  49.2827        472
# 38  3/23/20         Canada                    Ontario  51.2538        503
# 39  3/23/20         Canada               Saskatchewan  52.9399         66
# 40  3/23/20         Canada                     Quebec  52.9399        628
# 41  3/23/20         Canada  Newfoundland and Labrador  53.1355         24
# 42  3/23/20         Canada                   Manitoba  53.7609         20
# 43  3/23/20         Canada                    Alberta  53.9333        301

# %%
sns.lmplot(x='Lat',y='Confirmed',data=cc1,fit_reg=True)

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
print(cc1)
# Out:
#           Date Country/Region             Province/State      Lat  Confirmed
# 14321  3/23/20         Canada           Diamond Princess   0.0000          0
# 3595   3/23/20          China                     Hainan  19.1959        168
# 4339   3/23/20          China                      Macau  22.1667         24
# 3843   3/23/20          China                  Hong Kong  22.3000        356
# 3409   3/23/20          China                  Guangdong  23.3417       1415
# 3471   3/23/20          China                    Guangxi  23.8298        254
# 5021   3/23/20          China                     Yunnan  24.9740        176
# 3285   3/23/20          China                     Fujian  26.0789        313
# 3533   3/23/20          China                    Guizhou  26.8154        146
# 3967   3/23/20          China                      Hunan  27.6104       1018
# 4153   3/23/20          China                    Jiangxi  27.6140        936
# 5083   3/23/20          China                   Zhejiang  29.1832       1238
# 3223   3/23/20          China                  Chongqing  30.0572        578
# 4773   3/23/20          China                    Sichuan  30.6171        543
# 3905   3/23/20          China                      Hubei  30.9756      67800
# 4649   3/23/20          China                   Shanghai  31.2020        404
# 4897   3/23/20          China                      Tibet  31.6927          1
# 3099   3/23/20          China                      Anhui  31.8257        990
# 4091   3/23/20          China                    Jiangsu  32.9711        633
# 3781   3/23/20          China                      Henan  33.8820       1274
# 4525   3/23/20          China                    Shaanxi  35.1917        248
# 4463   3/23/20          China                    Qinghai  35.7452         18
# 4587   3/23/20          China                   Shandong  36.3427        768
# 4401   3/23/20          China                    Ningxia  37.2692         75
# 4711   3/23/20          China                     Shanxi  37.5777        134
# 2355   3/23/20         Canada             Grand Princess  37.6489         13
# 3347   3/23/20          China                      Gansu  37.8099        136
# 4835   3/23/20          China                    Tianjin  39.3054        141
# 3657   3/23/20          China                      Hebei  39.5490        319
# 3161   3/23/20          China                    Beijing  40.1824        537
# 4959   3/23/20          China                   Xinjiang  41.1129         76
# 4277   3/23/20          China                   Liaoning  41.2956        127
# 4215   3/23/20          China                      Jilin  43.6661         93
# 4029   3/23/20          China             Inner Mongolia  44.0935         75
# 2603   3/23/20         Canada                Nova Scotia  44.6820         41
# 2727   3/23/20         Canada       Prince Edward Island  46.5107          3
# 2479   3/23/20         Canada              New Brunswick  46.5653         17
# 3719   3/23/20          China               Heilongjiang  47.8620        484
# 2293   3/23/20         Canada           British Columbia  49.2827        472
# 2665   3/23/20         Canada                    Ontario  51.2538        503
# 2851   3/23/20         Canada               Saskatchewan  52.9399         66
# 2789   3/23/20         Canada                     Quebec  52.9399        628
# 2541   3/23/20         Canada  Newfoundland and Labrador  53.1355         24
# 2417   3/23/20         Canada                   Manitoba  53.7609         20
# 2231   3/23/20         Canada                    Alberta  53.9333        301
